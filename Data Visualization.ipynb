# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")

# %%
# Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='time')
plt.title('Scatter Plot of Total Bill vs Tip')
plt.show()

# %%
# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=tips, x='day', y='tip', hue='sex')
plt.title('Box Plot of Tips by Day')
plt.show()

# %%
# Bar Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=tips, x='day', y='total_bill', ci=None)
plt.title('Average Total Bill by Day')
plt.show()
# Out:
# /var/folders/r7/_qf_l8597dx_rlldg3l3l2_40000gn/T/ipykernel_3789/3819042682.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=tips, x='day', y='total_bill', ci=None)

# %%
# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=tips, x='total_bill', bins=20, kde=True)
plt.title('Histogram of Total Bills')
plt.show()
